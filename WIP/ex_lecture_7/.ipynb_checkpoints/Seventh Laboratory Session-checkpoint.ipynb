# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt

def AutoC(f, t):
    x=0.
    x_t=0.
    x_2=0.
    xx_t=0.
    j = len(f)-t
    for i in range(j):
        x+=f[i]
        x_t+=f[i+t]
        x_2+=f[i]**2
        xx_t+=f[i]*f[i+t]
    xx_t/=j
    x/=j
    x_2/=j
    x_t/=j
    return (xx_t-x_t*x)/(x_2-x**2)

def expo(x,a,b,c):
    return a*np.exp(-b*x)+c

plt.rcParams['figure.figsize'] = [16,9]

#Energy Autocorellation
k=np.loadtxt("MonteCarlo_NVT/e_inst.dat")

print(k)
ac=[]

n=150

x = np.arange(0,n,1)
for i in range(n):
    ac.append(AutoC(k,i))
plt.plot(x,ac,label="Data")

param, pvar = opt.curve_fit(expo,x,ac)

plt.plot(x, expo(x, *param), label="Fit");

print("Fit with a*e^(-b*x)+c")
print("a =", param[0], "; error = ", pvar[0][0])
print("b =", param[1], "; error = ", pvar[1][1])
print("c =", param[2], "; error = ", pvar[2][2])


plt.legend()
plt.grid(1)

plt.show()
# Out:
# [-8.71336  -8.44843  -8.26633  ... -0.534771 -0.534221 -0.541513]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-1a339f426b0d> in <module>()
#      39 plt.plot(x,ac,label="Data")
#      40
# ---> 41 param, pvar = opt.curve_fit(expo,x,ac)
#      42
#      43 plt.plot(x, expo(x, *param), label="Fit");
#
# ~/intelpython3/lib/python3.6/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     708     # NaNs can not be handled
#     709     if check_finite:
# --> 710         ydata = np.asarray_chkfinite(ydata)
#     711     else:
#     712         ydata = np.asarray(ydata)
#
# ~/intelpython3/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     459     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     460         raise ValueError(
# --> 461             "array must not contain infs or NaNs")
#     462     return a
#     463
#
# ValueError: array must not contain infs or NaNs

# %% [markdown]
# # L'errore non viene, le medio però sono giuste, WTF??????

# %%
#Data blocking
M=len(k)
L=np.arange(10,5000,100)
ind = 0
Error = np.zeros(len(L))
for block_size in L:
    block_number = int(M/block_size)
    ave = np.zeros(block_number)
    error = np.zeros(block_number)
    for iblock in range(block_number):
        for istep in range(block_size+1):
            ave[iblock]+=k[iblock*block_size+istep]
        ave[iblock]/=block_size
    for i in range(block_number):
        global_ave = 0.
        global_ave_2 = 0.
        for j in range(i+1):
            global_ave += ave[j]
            global_ave_2 += ave[j]**2
        global_ave /=(i+1)
        global_ave_2 /=(i+1)
        error = ((global_ave_2-global_ave**2)/(i+1))**0.5
    Error[ind]=error
    ind+=1
    
plt.plot(L,Error, marker="o")
plt.grid(1)
plt.show()

# %%
k=np.loadtxt("MonteCarlo_NVT/output.gave.0")
x=k[:,0]
y=k[:,1]
err = k[:,2]

plt.errorbar(x,y, yerr=err, linestyle="none", marker=".")
plt.show()

# %%
k=np.loadtxt("MonteCarlo_NVT/output.gofr.0")
x=k[:,0]
y=k[:,1]

plt.plot(x,y,linestyle="none", marker=".")
plt.show()

# %%
k=np.loadtxt("MolDyn/output.gofr.0")
x=k[:,0]
y=k[:,1]

plt.plot(x,y,linestyle="none", marker=".")
plt.show()
