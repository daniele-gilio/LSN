# %% [markdown]
# # Excercise 8.1, 8.2 and 8.3
# ## Energy is working, histogram is normalized but wrong (vmc), brownian motion stuff is ok

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16,9]

k=np.loadtxt("potential.dat", delimiter=";")
x=k[:,0]
y=k[:,1]
err=k[:,2]

plt.errorbar(x,y,yerr=err, marker=".")
plt.grid()
plt.show()

# %%
y=np.loadtxt("hist.dat")
x=np.linspace(-5.,5.,400)
plt.plot(x,y)

k=np.loadtxt("QMC_1D/probability.dat")
x=k[:,0]
y=k[:,1]
err=k[:,2]

plt.errorbar(x,y,yerr=err)
plt.grid()
plt.show()
